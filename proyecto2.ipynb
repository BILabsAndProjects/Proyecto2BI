# %%
import pandas as pd

# %%
iboca = pd.read_excel(r'Datos_aire/IBOCA-PM10-2020-1.xlsx', skiprows=4)

# %%
iboca = iboca.iloc[:-3]
iboca.tail(20)
# Out:
#                Unnamed: 0 Bolivia Unnamed: 2 Unnamed: 3 Carvajal - Sevillana  \
# 4351  2024-06-30 05:00:00      11      10.84      45.15                   22
# 4352  2024-06-30 06:00:00      13      11.92      49.66                   21
# 4353  2024-06-30 07:00:00      10      10.96      45.66                   17
# 4354  2024-06-30 08:00:00       9       9.98      41.58                   24
# 4355  2024-06-30 09:00:00      12      10.99      45.79                   17
# 4356  2024-06-30 10:00:00       9      10.04      41.85                    6
# 4357  2024-06-30 11:00:00       7        8.5      35.41                    7
# 4358  2024-06-30 12:00:00       5       6.75      28.12                   11
# 4359  2024-06-30 13:00:00      13       9.87      41.14                   24
# 4360  2024-06-30 14:00:00      10       9.94       41.4                    8
# 4361  2024-06-30 15:00:00       7       8.47      35.28                   28
# 4362  2024-06-30 16:00:00       8       8.23      34.31                   30
# 4363  2024-06-30 17:00:00       6       7.12      29.65                   22
# 4364  2024-06-30 18:00:00       4       5.56      23.15                   16
# 4365  2024-06-30 19:00:00      11       8.28      34.49                   30
# 4366  2024-06-30 20:00:00      11       9.64      40.16                   14
# 4367  2024-06-30 21:00:00       9       9.32      38.83                   12
# 4368  2024-06-30 22:00:00       8       8.66      36.08                   18
# 4369  2024-06-30 23:00:00       6       7.33      30.54                   29
# 4370  2024-07-01 00:00:00       7       7.17      29.85                   20
#
#      Unnamed: 5 Unnamed: 6 Ciudad Bolívar Unnamed: 8 Unnamed: 9  ...  \
# 4351      20.42       68.5             10       9.82      40.92  ...
# 4352      20.71      69.11              7       8.41      35.04  ...
# 4353      18.85       65.2              6        7.2      30.02  ...
# 4354      21.43      70.61              5        6.1      25.42  ...
# 4355      19.21      65.96              4       5.05      21.04  ...
# 4356       12.6      52.06              4       4.52      18.85  ...
# 4357        9.8      40.83              4       4.26      17.75  ...
# 4358       10.4      43.33             10       7.13      29.71  ...
# 4359       17.2      61.73             13      10.07      41.94  ...
# 4360       12.6      52.05             10      10.03       41.8  ...
# 4361       20.3      68.25              7       8.52      35.48  ...
# 4362      25.15      78.45              6       7.26      30.24  ...
# 4363      23.58      75.13             12       9.63      40.12  ...
# 4364      19.79      67.17             11      10.32      42.98  ...
# 4365       24.9      77.91              9       9.66      40.24  ...
# 4366      19.45      66.45              9       9.33      38.87  ...
# 4367      15.72      58.62             12      10.67      44.44  ...
# 4368      16.86      61.02             13      11.83      49.31  ...
# 4369      22.93      73.78             14      12.92      52.72  ...
# 4370      21.47       70.7             10      11.46      47.75  ...
#
#      Unnamed: 48   Usaquen Unnamed: 50 Unnamed: 51      Usme Unnamed: 53  \
# 4351       53.93  Sin data    Sin data    Sin data  Sin data         1.6
# 4352       59.72  Sin data    Sin data    Sin data         1         1.3
# 4353       57.36  Sin data    Sin data    Sin data         4        2.65
# 4354    Sin data  Sin data    Sin data    Sin data         6        4.32
# 4355       33.46  Sin data    Sin data    Sin data         9        6.66
# 4356        18.8  Sin data    Sin data    Sin data         6        6.33
# 4357       19.81  Sin data    Sin data    Sin data  Sin data        3.16
# 4358       20.32  Sin data    Sin data    Sin data  Sin data        1.58
# 4359       14.32  Sin data    Sin data    Sin data         2        1.79
# 4360        7.16  Sin data    Sin data    Sin data         5        3.39
# 4361        9.82  Sin data    Sin data    Sin data         2         2.7
# 4362       29.91  Sin data    Sin data    Sin data         3        2.85
# 4363       48.29  Sin data    Sin data    Sin data         6        4.43
# 4364       44.97  Sin data    Sin data    Sin data         1        2.71
# 4365        45.4  Sin data    Sin data    Sin data         4        3.36
# 4366       37.28  Sin data    Sin data    Sin data         7        5.18
# 4367       31.14  Sin data    Sin data    Sin data         8        6.59
# 4368       28.07  Sin data    Sin data    Sin data         7        6.79
# 4369       24.45  Sin data    Sin data    Sin data         7         6.9
# 4370       30.98  Sin data    Sin data    Sin data        12        9.45
#
#      Unnamed: 54 CDAR Unnamed: 56 Unnamed: 57
# 4351        6.66    9        8.38       34.91
# 4352        5.41    7        7.69       32.04
# 4353       11.03    6        6.84       28.52
# 4354       18.01    7        6.92       28.84
# 4355       27.75    6        6.46       26.91
# 4356       26.38    5        5.73       23.87
# 4357       13.18    5        5.47        22.8
# 4358        6.59    8        6.59       27.48
# 4359        7.46    7        6.77       28.23
# 4360       14.15    7        6.87       28.65
# 4361       11.24    6        6.49       27.02
# 4362       11.87    6        6.27       26.12
# 4363       18.44    5        5.82       24.23
# 4364        11.3    5        5.51       22.95
# 4365       13.98    5        5.32       22.15
# 4366       21.58    5        5.19       21.64
# 4367       27.45    5        5.12       21.33
# 4368       28.31    6        5.45       22.71
# 4369       28.74    6        5.66       23.58
# 4370       39.38    7        6.01       25.03
#
# [20 rows x 58 columns]

# %%
iboca = iboca.rename(columns={'Unnamed: 0': 'Fecha'})

# %%
iboca.head()
# Out:
#                  Fecha        Bolivia Unnamed: 2 Unnamed: 3  \
# 0         Fecha & Hora    PM2.5 µg/m3        NaN        NaN
# 1                  NaN  Concentración    NowCast      IBOCA
# 2  2024-01-01 00:00:00             26      24.16      76.36
# 3  2024-01-01 01:00:00             23      23.58      75.14
# 4  2024-01-01 02:00:00             18      20.79      69.27
#
#   Carvajal - Sevillana Unnamed: 5 Unnamed: 6 Ciudad Bolívar Unnamed: 8  \
# 0          PM2.5 µg/m3        NaN        NaN    PM2.5 µg/m3        NaN
# 1        Concentración    NowCast      IBOCA  Concentración    NowCast
# 2                   48      37.97     107.09             43      41.63
# 3                   72      54.99     148.99       Sin data   Sin data
# 4                  116      85.51     166.36       Sin data   Sin data
#
#   Unnamed: 9  ... Unnamed: 48        Usaquen Unnamed: 50 Unnamed: 51  \
# 0        NaN  ...         NaN    PM2.5 µg/m3         NaN         NaN
# 1      IBOCA  ...       IBOCA  Concentración     NowCast       IBOCA
# 2     116.11  ...       93.64             23       23.41       74.78
# 3   Sin data  ...       57.12             86        59.2      152.89
# 4   Sin data  ...       31.27             48        53.6      145.57
#
#             Usme Unnamed: 53 Unnamed: 54           CDAR Unnamed: 56  \
# 0    PM2.5 µg/m3         NaN         NaN    PM2.5 µg/m3         NaN
# 1  Concentración     NowCast       IBOCA  Concentración     NowCast
# 2             35       34.25       97.57       Sin data    Sin data
# 3             27        25.2       78.56             34       34.13
# 4             37       31.11       90.97             72       53.07
#
#   Unnamed: 57
# 0         NaN
# 1       IBOCA
# 2    Sin data
# 3       97.32
# 4      144.27
#
# [5 rows x 58 columns]
