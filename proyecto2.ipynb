# %%
import pandas as pd

# %%
iboca = pd.read_excel(r'Datos_aire/IBOCA-PM10-2020-1.xlsx', skiprows=4)
iboca.head()
# Out:
#             Unnamed: 0 Carvajal - Sevillana   Unnamed: 2 Unnamed: 3  \
# 0         Fecha & Hora           PM10 µg/m3          NaN        NaN
# 1                  NaN        Concentración  Media móvil      IBOCA
# 2  2020-01-01 00:00:00                   24           39      36.11
# 3  2020-01-01 01:00:00                   27           39      36.11
# 4  2020-01-01 02:00:00                   27           39      36.11
#
#             CDAR   Unnamed: 5 Unnamed: 6       Fontibon   Unnamed: 8  \
# 0     PM10 µg/m3          NaN        NaN     PM10 µg/m3          NaN
# 1  Concentración  Media móvil      IBOCA  Concentración  Media móvil
# 2             11           16      14.81             25           27
# 3             11           15      13.89             30           27
# 4              8           15      13.89             42           28
#
#   Unnamed: 9  ... Unnamed: 30           Suba  Unnamed: 32 Unnamed: 33  \
# 0        NaN  ...         NaN     PM10 µg/m3          NaN         NaN
# 1      IBOCA  ...       IBOCA  Concentración  Media móvil       IBOCA
# 2         25  ...       27.78              2           39       36.11
# 3         25  ...        28.7             67           40       37.04
# 4      25.93  ...       29.63             66           42       38.89
#
#            Tunal  Unnamed: 35 Unnamed: 36        Usaquen  Unnamed: 38  \
# 0     PM10 µg/m3          NaN         NaN     PM10 µg/m3          NaN
# 1  Concentración  Media móvil       IBOCA  Concentración  Media móvil
# 2             35           39       36.11              6           12
# 3             45           38       35.19             13           12
# 4             57           39       36.11             12           12
#
#   Unnamed: 39
# 0         NaN
# 1       IBOCA
# 2       11.11
# 3       11.11
# 4       11.11
#
# [5 rows x 40 columns]

# %%
iboca = iboca.iloc[:-3]
iboca.tail(20)
# Out:
#                Unnamed: 0 Carvajal - Sevillana Unnamed: 2 Unnamed: 3 CDAR  \
# 4351  2020-06-30 05:00:00                   78         42      38.89    8
# 4352  2020-06-30 06:00:00                  111         46      42.59    7
# 4353  2020-06-30 07:00:00                   99         49      45.37   13
# 4354  2020-06-30 08:00:00                   96         51      47.22   24
# 4355  2020-06-30 09:00:00                   93         53      49.07   22
# 4356  2020-06-30 10:00:00                   93         55       50.1   33
# 4357  2020-06-30 11:00:00                   38         10       9.26   64
# 4358  2020-06-30 12:00:00                  105         59      52.12   36
# 4359  2020-06-30 13:00:00                   72         60      52.62   36
# 4360  2020-06-30 14:00:00                   31         14      12.96   33
# 4361  2020-06-30 15:00:00                   89         64      54.64   34
# 4362  2020-06-30 16:00:00                  137         69      57.16   27
# 4363  2020-06-30 17:00:00                   82         72      58.67   20
# 4364  2020-06-30 18:00:00                   68         73      59.17   27
# 4365  2020-06-30 19:00:00                   85         75      60.18   31
# 4366  2020-06-30 20:00:00                   93         78      61.69   28
# 4367  2020-06-30 21:00:00                   81         80       62.7   28
# 4368  2020-06-30 22:00:00                   76         81      63.21   39
# 4369  2020-06-30 23:00:00                  116         84      64.72   35
# 4370  2020-07-01 00:00:00                   72         84      64.72   42
#
#      Unnamed: 5 Unnamed: 6 Fontibon Unnamed: 8 Unnamed: 9  ... Unnamed: 30  \
# 4351          5       4.63       25         17      15.74  ...        9.26
# 4352          5       4.63       36         18      16.67  ...       10.19
# 4353          6       5.56       50         20      18.52  ...       12.04
# 4354          6       5.56       77         23       21.3  ...       12.96
# 4355          7       6.48       71         26      24.07  ...       13.89
# 4356          8       7.41       60         28      25.93  ...       14.81
# 4357         30      27.78       27         19      17.59  ...        6.48
# 4358         11      10.19       41         31       28.7  ...    Sin data
# 4359         13      12.04       37         33      30.56  ...    Sin data
# 4360         34      31.48       32         23       21.3  ...    Sin data
# 4361         15      13.89       34         35      32.41  ...    Sin data
# 4362         16      14.81       39         36      33.33  ...    Sin data
# 4363         17      15.74       38         37      34.26  ...    Sin data
# 4364         17      15.74       38         38      35.19  ...    Sin data
# 4365         19      17.59       36         39      36.11  ...       24.07
# 4366         20      18.52       36         40      37.04  ...          25
# 4367         21      19.44       43         40      37.04  ...          25
# 4368         22      20.37       81         42      38.89  ...       25.93
# 4369         23       21.3       71         43      39.81  ...       25.93
# 4370         25      23.15       53         44      40.74  ...       26.85
#
#           Suba Unnamed: 32 Unnamed: 33     Tunal Unnamed: 35 Unnamed: 36  \
# 4351        38          19       17.59         8           4         3.7
# 4352        71          21       19.44         6           5        4.63
# 4353        40          23        21.3         6           5        4.63
# 4354        31          23        21.3        13           5        4.63
# 4355        36          24       22.22        23           6        5.56
# 4356        35          25       23.15        20           6        5.56
# 4357  Sin data    Sin data    Sin data  Sin data    Sin data    Sin data
# 4358        34          27          25        34           9        8.33
# 4359        30          28       25.93  Sin data           9        8.33
# 4360        29          29       26.85  Sin data           9        8.33
# 4361        42          30       27.78  Sin data           9        8.33
# 4362        26          30       27.78  Sin data           9        8.33
# 4363        28          31        28.7  Sin data          10        9.26
# 4364        40          33       30.56  Sin data          10        9.26
# 4365        34    Sin data    Sin data        43          34       31.48
# 4366        34    Sin data    Sin data        38          35       32.41
# 4367        37    Sin data    Sin data        35          35       32.41
# 4368        32    Sin data    Sin data        43          36       33.33
# 4369        31          41       37.96        49          37       34.26
# 4370        39          41       37.96        32          37       34.26
#
#        Usaquen Unnamed: 38 Unnamed: 39
# 4351  Sin data    Sin data    Sin data
# 4352  Sin data    Sin data    Sin data
# 4353  Sin data    Sin data    Sin data
# 4354  Sin data    Sin data    Sin data
# 4355  Sin data    Sin data    Sin data
# 4356  Sin data    Sin data    Sin data
# 4357  Sin data    Sin data    Sin data
# 4358  Sin data    Sin data    Sin data
# 4359  Sin data    Sin data    Sin data
# 4360  Sin data    Sin data    Sin data
# 4361  Sin data    Sin data    Sin data
# 4362  Sin data    Sin data    Sin data
# 4363  Sin data    Sin data    Sin data
# 4364  Sin data    Sin data    Sin data
# 4365  Sin data          10        9.26
# 4366  Sin data          11       10.19
# 4367  Sin data          11       10.19
# 4368  Sin data          12       11.11
# 4369  Sin data          13       12.04
# 4370  Sin data          13       12.04
#
# [20 rows x 40 columns]

# %%
#iboca = iboca.rename(columns={'Unnamed: 0': 'Fecha'})

# %% [markdown]
# TO-DO datos:
# - unificar por localidad (media)
# - pasar a filas con columnas: fechas, localidad, datos de aire
# -

# %%
cols = iboca.columns
print(cols)
# Out:
# Index(['Fecha', 'Bolivia', 'Unnamed: 2', 'Unnamed: 3', 'Carvajal - Sevillana',
#        'Unnamed: 5', 'Unnamed: 6', 'Ciudad Bolívar', 'Unnamed: 8',
#        'Unnamed: 9', 'Colina', 'Unnamed: 11', 'Unnamed: 12', 'Fontibon',
#        'Unnamed: 14', 'Unnamed: 15', 'Guaymaral', 'Unnamed: 17', 'Unnamed: 18',
#        'Jazmín', 'Unnamed: 20', 'Unnamed: 21', 'Kennedy', 'Unnamed: 23',
#        'Unnamed: 24', 'Las Ferias', 'Unnamed: 26', 'Unnamed: 27',
#        'MinAmbiente', 'Unnamed: 29', 'Unnamed: 30', 'Móvil 7ma', 'Unnamed: 32',
#        'Unnamed: 33', 'Móvil Fontibón', 'Unnamed: 35', 'Unnamed: 36',
#        'Puente Aranda', 'Unnamed: 38', 'Unnamed: 39', 'San Cristobal',
#        'Unnamed: 41', 'Unnamed: 42', 'Suba', 'Unnamed: 44', 'Unnamed: 45',
#        'Tunal', 'Unnamed: 47', 'Unnamed: 48', 'Usaquen', 'Unnamed: 50',
#        'Unnamed: 51', 'Usme', 'Unnamed: 53', 'Unnamed: 54', 'CDAR',
#        'Unnamed: 56', 'Unnamed: 57'],
#       dtype='object')

# %%
new_cols = {'Unnamed: 0': 'Fecha'}
medida = ['Concentracion', 'NowCast', 'IBOCA']
#prev_name = cols[1]
#i = 0
for col in cols[1:]:
    if 'Unnamed' not in col:
        prev_name = col
        i = 0
    new_name = prev_name + " " + medida[i]
    i += 1
    new_cols[col] = new_name
print(new_cols)
# Out:
# {'Unnamed: 0': 'Fecha', 'Bolivia': 'Bolivia Concentracion', 'Unnamed: 2': 'Bolivia NowCast', 'Unnamed: 3': 'Bolivia IBOCA', 'Carvajal - Sevillana': 'Carvajal - Sevillana Concentracion', 'Unnamed: 5': 'Carvajal - Sevillana NowCast', 'Unnamed: 6': 'Carvajal - Sevillana IBOCA', 'Ciudad Bolívar': 'Ciudad Bolívar Concentracion', 'Unnamed: 8': 'Ciudad Bolívar NowCast', 'Unnamed: 9': 'Ciudad Bolívar IBOCA', 'Colina': 'Colina Concentracion', 'Unnamed: 11': 'Colina NowCast', 'Unnamed: 12': 'Colina IBOCA', 'Fontibon': 'Fontibon Concentracion', 'Unnamed: 14': 'Fontibon NowCast', 'Unnamed: 15': 'Fontibon IBOCA', 'Guaymaral': 'Guaymaral Concentracion', 'Unnamed: 17': 'Guaymaral NowCast', 'Unnamed: 18': 'Guaymaral IBOCA', 'Jazmín': 'Jazmín Concentracion', 'Unnamed: 20': 'Jazmín NowCast', 'Unnamed: 21': 'Jazmín IBOCA', 'Kennedy': 'Kennedy Concentracion', 'Unnamed: 23': 'Kennedy NowCast', 'Unnamed: 24': 'Kennedy IBOCA', 'Las Ferias': 'Las Ferias Concentracion', 'Unnamed: 26': 'Las Ferias NowCast', 'Unnamed: 27': 'Las Ferias IBOCA', 'MinAmbiente': 'MinAmbiente Concentracion', 'Unnamed: 29': 'MinAmbiente NowCast', 'Unnamed: 30': 'MinAmbiente IBOCA', 'Móvil 7ma': 'Móvil 7ma Concentracion', 'Unnamed: 32': 'Móvil 7ma NowCast', 'Unnamed: 33': 'Móvil 7ma IBOCA', 'Móvil Fontibón': 'Móvil Fontibón Concentracion', 'Unnamed: 35': 'Móvil Fontibón NowCast', 'Unnamed: 36': 'Móvil Fontibón IBOCA', 'Puente Aranda': 'Puente Aranda Concentracion', 'Unnamed: 38': 'Puente Aranda NowCast', 'Unnamed: 39': 'Puente Aranda IBOCA', 'San Cristobal': 'San Cristobal Concentracion', 'Unnamed: 41': 'San Cristobal NowCast', 'Unnamed: 42': 'San Cristobal IBOCA', 'Suba': 'Suba Concentracion', 'Unnamed: 44': 'Suba NowCast', 'Unnamed: 45': 'Suba IBOCA', 'Tunal': 'Tunal Concentracion', 'Unnamed: 47': 'Tunal NowCast', 'Unnamed: 48': 'Tunal IBOCA', 'Usaquen': 'Usaquen Concentracion', 'Unnamed: 50': 'Usaquen NowCast', 'Unnamed: 51': 'Usaquen IBOCA', 'Usme': 'Usme Concentracion', 'Unnamed: 53': 'Usme NowCast', 'Unnamed: 54': 'Usme IBOCA', 'CDAR': 'CDAR Concentracion', 'Unnamed: 56': 'CDAR NowCast', 'Unnamed: 57': 'CDAR IBOCA'}

# %%
iboca = iboca.rename(columns=new_cols)
iboca = iboca.iloc[2:]
iboca = iboca.replace('Sin data', 'NaN')
iboca.head()
# Out:
# C:\Users\laura\AppData\Local\Temp\ipykernel_18556\1675617760.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iboca = iboca.replace('Sin data', 'NaN')
#                 Fecha Bolivia Concentracion Bolivia NowCast Bolivia IBOCA  \
# 4 2024-01-01 02:00:00                    18           20.79         69.27
# 5 2024-01-01 03:00:00                    13           16.89         61.08
# 6 2024-01-01 04:00:00                    24           20.45         68.56
# 7 2024-01-01 05:00:00                    23           21.73         71.24
# 8 2024-01-01 06:00:00                    29           25.36         78.89
#
#   Carvajal - Sevillana Concentracion Carvajal - Sevillana NowCast  \
# 4                                116                        85.51
# 5                                106                        95.76
# 6                                 44                        69.88
# 7                                 37                        53.44
# 8                                 37                        45.22
#
#   Carvajal - Sevillana IBOCA Ciudad Bolívar Concentracion  \
# 4                     166.36                          NaN
# 5                     171.62                          NaN
# 6                     158.36                          NaN
# 7                     145.18                          NaN
# 8                     124.94                          NaN
#
#   Ciudad Bolívar NowCast Ciudad Bolívar IBOCA  ... Tunal IBOCA  \
# 4                    NaN                  NaN  ...       31.27
# 5                    NaN                  NaN  ...       62.89
# 6                    NaN                  NaN  ...       87.34
# 7                    NaN                  NaN  ...       96.41
# 8                    NaN                  NaN  ...      103.09
#
#   Usaquen Concentracion Usaquen NowCast Usaquen IBOCA Usme Concentracion  \
# 4                    48            53.6        145.57                 37
# 5                    49            51.3        139.91                 29
# 6                    35           43.15        119.84                 21
# 7                    35           39.08        109.81                 30
# 8                    26           32.54         93.98                 18
#
#   Usme NowCast Usme IBOCA CDAR Concentracion CDAR NowCast CDAR IBOCA
# 4        31.11      90.97                 72        53.07     144.27
# 5        30.05      88.76                 73        63.04     154.86
# 6        25.53      79.24                 53        58.03     152.29
# 7        27.76      83.94                 48        53.02     144.14
# 8        22.88      73.68                 45        49.01     134.27
#
# [5 rows x 58 columns]
